# %% [markdown]
# # Kafka Demo
#
# ### Connect to Kafka Broker Server
# ```
# ssh -L <local_port>:localhost:<remote_port> <user>@<remote_server> -NTf
# ```
# Find how to connect to Kafka server on Canvas lab 2 assignment page.
#
# ### To kill connection
# ```
# lsof -ti:<local_port> | xargs kill -9
# ```
#
# ### Setup
# ```
# python -m pip install kafka-python
# ```

# %%
import os
from datetime import datetime
from json import dumps, loads
from time import sleep
from random import randint
from kafka import KafkaConsumer, KafkaProducer

# Update this for your own recitation section :)
topic = 'recitation-d' # x could be b, c, d, e, f

# %% [markdown]
# ### Producer Mode -> Writes Data to Broker

# %%
# Create a producer to write data to kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaProducer.html

# [TODO]: Replace '...' with the address of your Kafka bootstrap server
producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                        value_serializer=lambda x: dumps(x).encode('utf-8'))

# [TODO]: Add cities of your choice
cities = ['San Francisco', 'Los Angeles', 'Seattle']

# Write data via the producer
print("Writing to Kafka Broker")
for i in range(10):
    data = f'{datetime.now().strftime("%Y-%m-%d %H:%M:%S")},{cities[randint(0,len(cities)-1)]},{randint(18, 32)}ºC'
    print(f"Writing: {data}")
    producer.send(topic=topic, value=data)
    sleep(1)
# Out:
# Writing to Kafka Broker
# Writing: 2025-01-24 11:16:34,Seattle,32ºC
# Writing: 2025-01-24 11:16:35,San Francisco,18ºC
# Writing: 2025-01-24 11:16:36,San Francisco,28ºC
# Writing: 2025-01-24 11:16:37,San Francisco,27ºC
# Writing: 2025-01-24 11:16:38,Seattle,20ºC
# Writing: 2025-01-24 11:16:39,Seattle,22ºC
# Writing: 2025-01-24 11:16:40,Seattle,20ºC
# Writing: 2025-01-24 11:16:41,Los Angeles,22ºC
# Writing: 2025-01-24 11:16:42,Seattle,18ºC
# Writing: 2025-01-24 11:16:43,Seattle,30ºC
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Consumer Mode -> Reads Data from Broker

# %%
# Create a consumer to read data from kafka
# Ref: https://kafka-python.readthedocs.io/en/master/apidoc/KafkaConsumer.html

# [TODO]: Complete the missing ... parameters/arguments using the Kafka documentation
consumer = KafkaConsumer(
    topic,
    bootstrap_servers=['localhost:9092'],
    auto_offset_reset='earliest', #Experiment with different values
    # Commit that an offset has been read
    enable_auto_commit=True,
    # How often to tell Kafka, an offset has been read
    auto_commit_interval_ms=1000
)

print('Reading Kafka Broker')
for message in consumer:
    message = message.value.decode()
    # Default message.value type is bytes!
    print(loads(message))
    os.system(f"echo {message} >> kafka_log.csv")
# Out:
# Reading Kafka Broker
# 2025-01-23 15:15:31,Denver,23ºC
# 2025-01-23 15:15:32,Denver,27ºC
# 2025-01-23 15:15:33,San Francisco,22ºC
# 2025-01-23 15:15:34,Denver,23ºC
# 2025-01-23 15:15:35,San Francisco,28ºC
# 2025-01-23 15:15:36,Denver,29ºC
# 2025-01-23 15:15:37,San Francisco,26ºC
# 2025-01-23 15:15:38,Denver,23ºC
# 2025-01-23 15:15:39,San Francisco,18ºC
# 2025-01-23 15:15:40,San Francisco,25ºC
# 2025-01-23 15:32:11,Los Angeles,29ºC
# 2025-01-23 15:32:12,Los Angeles,24ºC
# 2025-01-24 11:03:37,Rio de Janeiro, Tokyo,26ºC
# 2025-01-24 11:03:38,Rio de Janeiro, Tokyo,19ºC
# 2025-01-24 11:03:39,Berlin,20ºC
# 2025-01-24 11:03:40,Berlin,32ºC
# 2025-01-24 11:03:41,Rio de Janeiro, Tokyo,25ºC
# 2025-01-24 11:03:42,Berlin,18ºC
# 2025-01-24 11:04:20,Kathmandu,28ºC
# 2025-01-24 11:04:21,San Francisco,24ºC
# 2025-01-24 11:04:22,Kathmandu,27ºC
# 2025-01-24 11:04:23,Kathmandu,26ºC
# 2025-01-24 11:04:24,New York,19ºC
# 2025-01-24 11:04:25,New York,31ºC
# 2025-01-24 11:04:26,San Francisco,22ºC
# 2025-01-24 11:04:27,Kathmandu,19ºC
# 2025-01-24 11:04:28,Los Angeles,30ºC
# 2025-01-24 11:04:28,San Francisco,24ºC
# 2025-01-24 11:04:29,Denver,27ºC
# 2025-01-24 11:04:29,New York,24ºC
# 2025-01-24 11:04:30,Denver,18ºC
# 2025-01-24 11:04:31,Denver,29ºC
# 2025-01-24 11:04:32,Los Angeles,21ºC
# 2025-01-24 11:04:33,Los Angeles,31ºC
# 2025-01-24 11:04:34,Los Angeles,20ºC
# 2025-01-24 11:04:35,Los Angeles,30ºC
# 2025-01-24 11:04:36,Los Angeles,23ºC
# 2025-01-24 11:04:37,Denver,18ºC
# 2025-01-24 11:06:27,Kathmandu,23ºC
# 2025-01-24 11:06:28,San Francisco,18ºC
# 2025-01-24 11:06:29,New York,32ºC
# 2025-01-24 11:06:30,Kathmandu,20ºC
# 2025-01-24 11:06:31,San Francisco,29ºC
# 2025-01-24 11:06:32,San Francisco,25ºC
# 2025-01-24 11:06:33,San Francisco,24ºC
# 2025-01-24 11:06:34,San Francisco,25ºC
# 2025-01-24 11:06:35,Kathmandu,27ºC
# 2025-01-24 11:06:36,San Francisco,28ºC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#       5 consumer = KafkaConsumer(
#       6     topic,
#       7     bootstrap_servers=['localhost:9092'],
#    (...)
#      12     auto_commit_interval_ms=1000
#      13 )
#      15 print('Reading Kafka Broker')
# ---> 16 for message in consumer:
#      17     message = message.value.decode()
#      18     # Default message.value type is bytes!
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/Desktop/17445/mlip-kafka-lab/env/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/miniforge3/envs/cmu/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Use kcat!
# It's a CLI (Command Line Interface). Previously known as kafkacat
#
#
# Ref: https://docs.confluent.io/platform/current/app-development/kafkacat-usage.html

# %%
#kcat command: connect to local Kafka broker, specify a topic, and consume messages from the earliest offset

# kcat -b localhost:9092 -t recitation-d -C
